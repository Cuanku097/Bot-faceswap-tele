# %% [markdown]
# <a href="https://colab.research.google.com/github/Cuanku097/Bot-faceswap-tele/blob/master/Copy_of_Flux_1_dev_PuLID_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Update
# !apt-get update

# %%
# !apt-get install -y wget aria2 libgl1-mesa-glx

# %%
# !git clone https://github.com/comfyanonymous/ComfyUI.git

# %%
# %cd ComfyUI
# !pip install -r requirements.txt

# %%
#Install Pinggy Tunel
# !pip install pinggy

# %%
# !phyton main.py --listen 0.0.0.0
